# %%
import pandas as pd

# import normalization library
import numpy as np
from sklearn import preprocessing

csv_data = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/shopping_data.csv')
print("=== CSV head ===")
print(csv_data.head())
# Out:
# === CSV head ===
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
print("=== CSV columns ===")
print(csv_data.columns)
# Out:
# === CSV columns ===
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
print("=== CSV specific row ===")
print(csv_data.iloc[3])

print("\n=== CSV specific rows ===")
print(csv_data.iloc[2:7])
# print from row 2 to 6

# csv_data['Age'].iloc[3]
# prints Age column of the third row
# Out:
# === CSV specific row ===
# CustomerID                     4
# Genre                     Female
# Age                           23
# Annual Income (k$)            16
# Spending Score (1-100)        77
# Name: 3, dtype: object
#
# === CSV specific rows ===
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6

# %%
print("=== CSV stats ===")
# print(csv_data.describe(include='all'))

print(csv_data.describe(exclude='O'))
# remove all NaN value from stats table
print("\nEND")
# Out:
# === CSV stats ===
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000
#
# END

# %%
# NULL/NaN data checking

csv_data = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/shopping_data_missingvalue.csv')
print(csv_data.isnull().values.any())
print("\n=== CSV mean ===")
print(csv_data.mean())

print('\n=== dataset before fillna ===')
print(csv_data.head(10))

# replace NaN/missing value with 
print("\n=== dataset with fillna ===")
csv_data = csv_data.fillna(csv_data.mean())
#fillna with .median()
print(csv_data.head(10))
# Out:
# True
#
# === CSV mean ===
# CustomerID                100.500000
# Age                        38.939698
# Annual Income (k$)         61.005051
# Spending Score (1-100)     50.489899
# dtype: float64
#
# === dataset before fillna ===
#    CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                    39.0
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                 NaN                     6.0
# 3           4  Female  23.0                16.0                    77.0
# 4           5  Female  31.0                17.0                     NaN
# 5           6  Female  22.0                 NaN                    76.0
# 6           7  Female  35.0                18.0                     6.0
# 7           8  Female  23.0                18.0                    94.0
# 8           9    Male  64.0                19.0                     NaN
# ...

# %%
# Normalization method
# K mean
# Min-max, Zscore, Decimal scaling, softmax, sigmoid

# Open file in python 
# readline(), Read only per row, partition to arrays
# file = open('PATH', 'r/w')
# content = file.read()
# file.close()
# print(content)
# writeline/s() pass an array
# OOP concepts

print("=== datase shape ===")
dataset = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/retail_raw_reduced.csv')
# print("Ukuran dataset: %d baris dan %d kolom\n" % dataset.shape)
# print(dataset.head())

print("\n=== Dataframe & modify column ===")
# df = pd.DataFrame(dataset, columns=[], index=[])

# Square a single row
# df = df.apply(lambda x: np.square(x) if x.name == 'RowName' else x, axis=1)

# Square multiple row
# df = df.apply(lambda x: np.square(x) if x.name in ['RowName', 'RowName'] else x, axis=1)

# Take data from other column
# dataset['order_month'] = dataset['order_date'].apply(lambda x:datetime.datetime.strptime(x, "%Y-%m-%d"). strftime('%Y-%m'))

# df = df.assign(Percentage lambda = x: (x[ColumnName] * 100%))
# Out:
# === pyplot ===
# Ukuran dataset: 5000 baris dan 9 kolom
#
#    order_id  order_date  customer_id             city     province product_id  \
# 0   1703458  2019-10-17        14004  Jakarta Selatan  DKI Jakarta      P1910
# 1   1706815  2019-10-24        17220  Jakarta Selatan  DKI Jakarta      P2934
# 2   1710718  2019-11-03        16518    Jakarta Utara  DKI Jakarta      P0908
# 3   1683592  2019-08-19        16364    Jakarta Barat  DKI Jakarta      P0128
# 4   1702573  2019-10-16        15696    Jakarta Timur  DKI Jakarta      P2968
#
#      brand  quantity  item_price
# 0  BRAND_J        10      740000
# 1  BRAND_R         2      604000
# 2  BRAND_C         8     1045000
# 3  BRAND_A         4      205000
# 4  BRAND_R         2     4475000

# %%
# sololearn
import numpy as np
heights = [189, 170, 189, 163, 183, 171, 185, 168, 173, 183, 173, 173, 175, 178, 183, 193, 178, 173, 174, 183, 183, 180, 168, 180, 170, 178, 182, 180, 183, 178, 182, 188, 175, 179, 183, 193, 182, 183, 177, 185, 188, 188, 182, 185, 191]

ages = [57, 61, 57, 57, 58, 57, 61, 54, 68, 51, 49, 64, 50, 48, 65, 52, 56, 46, 54, 49, 51, 47, 55, 55, 54, 42, 51, 56, 55, 51, 54, 51, 60, 62, 43, 55, 56, 61, 52, 69, 64, 46, 54, 47, 70]

heights_and_ages = heights + ages
heights_and_ages_arr = np.array(heights_and_ages)
heights_and_ages_arr = heights_and_ages_arr.reshape((2, 45))

# access first column (height and age of president)
print(heights_and_ages_arr[:, 0])
# Out:
# [189  57]

# %%
# aggregate function

# monthly_amount = dataset.groupby('order_month')['gmv'].sum().reset_index()
# import matplotlib.pyplot as plt
# plt.plot(x.axis, y.axis)

# plt.figure(figsize=(15,5)) 
# 15 inches for x-axis, 5 y-axis
# dataset.groupby(['order_month'])['gmv'].sum().plot()

# plt.title('Monthly GMV Year 2019', loc='center', pad=40, fontSize=20, color='blue')
# plt.xlabel('Order Month', fontSize=15)
# plt.ylabel('Total Amount', fontSize=15)
# plt.grid(color='darkgray', linestyle=':', linewidth=0.5)

# Import library yang dibutuhkan
import datetime
import pandas as pd
import matplotlib.pyplot as plt
# Baca dataset retail_raw_reduced.csv
dataset = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/retail_raw_reduced.csv')
# Buat kolom order_month
dataset['order_month'] = dataset['order_date'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d").strftime('%Y-%m'))
# Buat kolom gmv
dataset['gmv'] = dataset['item_price'] * dataset['quantity']
# Plot grafik sesuai dengan instruksi
plt.figure(figsize=(10, 5))
dataset[dataset['order_month']=='2019-12'].groupby(['order_date'])['customer_id'].sum().plot(color='red', marker='.', linewidth=2)
plt.title('Daily Number of Customers', loc='left', pad=40, fontSize=20, color='orange')
plt.xlabel('Order Date', fontsize=15, color='blue')
plt.ylabel('Number of Customers', fontsize=15, color='blue')
plt.grid(color='darkgray', linestyle=':', linewidth=0.5)
plt.ylim(ymin=0)
plt.show()
# Out:
# False
